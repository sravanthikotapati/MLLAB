# %%
import pandas as pd
df=pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model-year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  396.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.189394  2970.424623
# std      7.815984    1.701004    104.269838   38.402030   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model-year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model-year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ...

# %%
names=['mpg','cylinders','displacement','horsepower','weight','acceleration',
      'model-year']

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model-year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %%
df.shape
# Out:
# (398, 7)

# %%
df_clean=df.applymap(lambda x: np.nan if x == '?' else x).dropna()
df_clean
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model-year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
df = df[df['cylinders'].apply(lambda x: str(x).isdigit())]
df['cylinders'] = pd.to_numeric(df['cylinders'])

# Now you can use the 'data' DataFrame to train your machine learning model

# %%
X = df_clean[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model-year']]
y = df_clean['mpg']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,test_size=0.2)

# %%
print(X)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model-year
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
# [396 rows x 6 columns]

# %%
print(y)
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 396, dtype: float64

# %%
print(X.shape)
print(y.shape)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (396, 6)
# (396,)
# (316, 6)
# (80, 6)
# (316,)
# (80,)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([15.08957736, 25.15596599, 26.9397173 , 26.24057997, 15.45471069,
#        21.20124617, 24.73894109, 20.89286696, 10.63614473, 29.44502568,
#        30.44333497, 12.6188063 , 28.33736565, 28.60620292, 32.28855251,
#        22.40943145, 12.22014934, 15.99738193, 33.38293726, 32.68392408,
#        31.34894564, 18.01724737, 26.02416001, 25.34317362, 26.82725493,
#        19.90116001, 20.37086894, 22.60928747, 15.99840977, 27.99731716,
#        12.98530759, 29.57700492, 29.93846667, 29.20534862, 20.80344549,
#         9.74646739, 10.66586928, 11.58462161, 15.2365213 , 28.76715722,
#         9.07795263, 24.42363999, 17.868587  , 29.38649169, 31.34830326,
#        28.26945575, 26.16349425, 25.77224331,  5.61683646, 31.85963208,
#        18.4201784 , 23.42622834, 16.21195707, 13.63122705, 20.11401967,
#        21.66645256, 25.64112919, 22.42521296, 16.04667879, 24.24903948,
#        30.22183012, 33.16602002, 14.11011403, 17.82097947, 23.52616802,
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
res=r2_score(y_test,y_pred)
res
# Out:
# 0.7705194644638274

# %%
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 15.185517310022794
# 2.8248457523329273

# %%
list(zip(names[1:8], model.coef_))
# Out:
# [('cylinders', -0.20011767758621435),
#  ('displacement', 0.010085433609127026),
#  ('horsepower', -0.025288471250043035),
#  ('weight', -0.006562883215196874),
#  ('acceleration', -0.08619313257855468),
#  ('model-year', 0.7266565957092731)]

# %%
import numpy as np
import matplotlib.pyplot as plt
y_pred = model.predict(X_train)
mse = np.mean((y_pred - y_train) ** 2)
rsq = model.score(X_train, y_train)
print("Mean Squared Error: %.4f \n R-squared: %.4f" % (mse,rsq))
# Out:
# Mean Squared Error: 11.0105
#  R-squared: 0.8164

# %%
y_pred_ = model.predict(X_test)
mse_ = np.mean((y_pred_ - y_test) ** 2)
rsq_ = model.score(X_test, y_test)

print("Mean Squared Error: %.4f \n R-squared: %.4f" % (mse_,rsq_))
# Out:
# Mean Squared Error: 15.1855
#  R-squared: 0.7705

# %%
plt.scatter(model.predict(X_train), model.predict(X_train)-y_train)
plt.plot([-5,40],[0,0], color = "red")
plt.scatter(model.predict(X_test), model.predict(X_test)-y_test, color = "yellow")

# %%
import pandas as pd
df=pd.read_csv('auto-mpg.csv')

# %%
mean1=df['cylinders'].mean()
print(mean1)
# Out:
# 5.454773869346734

# %%
mean2=df['horsepower'].mean()
print(mean2)
# Out:
# 104.18939393939394

# %%
mode=df['cylinders'].mode()
mode
# Out:
# 0    4
# Name: cylinders, dtype: int64

# %%
mode=df['horsepower'].mode()
mode
# Out:
# 0    150.0
# Name: horsepower, dtype: float64

# %%
df.max()
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# model-year        82.0
# dtype: float64

# %%
df.mean()
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# horsepower       104.189394
# weight          2970.424623
# acceleration      15.568090
# model-year        76.010050
# dtype: float64

# %%
df.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model-year
# 0  13.0        4.0          97.0       150.0    1985          14.5        73.0
# 1   NaN        NaN           NaN         NaN    2130           NaN         NaN

# %%
df.std()
# Out:
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# horsepower       38.402030
# weight          846.841774
# acceleration      2.757689
# model-year        3.697627
# dtype: float64

# %%
df.var()
# Out:
# mpg                 61.089611
# cylinders            2.893415
# displacement     10872.199152
# horsepower        1474.715938
# weight          717140.990526
# acceleration         7.604848
# model-year          13.672443
# dtype: float64

# %%
df.min()
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# model-year        70.0
# dtype: float64

# %%
df.median()
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        92.0
# weight          2803.5
# acceleration      15.5
# model-year        76.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.boxplot(df)
plt.title('Boxplot of Dataset')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
df.boxplot()

# Add a title and labels to the axes
plt.title('Boxplot of Dataset')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
# Out:
# Text(0, 0.5, 'Y-axis label')

# %%
df.boxplot(column='cylinders')

# Add a title and labels to the axes
plt.title('Boxplot of Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='displacement')
plt.title('Boxplot of displacement')
plt.xlabel('displacement')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='horsepower')
plt.title('Boxplot of horsepower')
plt.xlabel('horsepower')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='weight')
plt.title('Boxplot of weight')
plt.xlabel('weight')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='acceleration')
plt.title('Boxplot of acceleration')
plt.xlabel('acceleration')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='model-year')
plt.title('Boxplot of model-year')
plt.xlabel('model-year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='whitegrid')
data = sns.load_dataset("mpg")
plt.figure(figsize=(10, 6))
sns.boxplot(x="cylinders", y="mpg",data=data)
plt.xlabel('cylinders')
plt.ylabel('MPG')
plt.title('Boxplot of MPG by cylinders')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='whitegrid')
data = sns.load_dataset("mpg")
selected_attributes = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration"]
sns.pairplot(data[selected_attributes])
plt.show()

# %%
cylinders_counts = data['cylinders'].value_counts()
print(cylinders_counts)
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df.hist( )
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model-year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.histplot(x='cylinders',data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='Count'>

# %%
sns.histplot(x='mpg',data=data)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Count'>

# %%
attributes = df.columns
plt.figure(figsize=(10, 6))
plt.title('Box Plots for Different Attributes')
for i, attribute in enumerate(attributes):
    plt.subplot(1, len(attributes), i + 1)
    plt.boxplot(df[attribute])
    plt.title(attribute)
    plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model-year'],
#       dtype='object')

# %%
if 'mpg' in df.columns:
    summary = df.describe()
    minimum = summary.loc['min', 'mpg']
    maximum = summary.loc['max', 'mpg']
    Q1 = summary.loc['25%', 'mpg']
    median = summary.loc['50%', 'mpg']  # Median is also called the second quartile (Q2)
    Q3 = summary.loc['75%', 'mpg']

    print("Minimum value:", minimum)
    print("Maximum value:", maximum)
    print("First quartile (Q1):", Q1)
    print("Median (Q2):", median)
    print("Third quartile (Q3):", Q3)
    import pandas as pd
else:
    print("The 'mpg' column does not exist in the DataFrame.")
# Out:
# Minimum value: 9.0
# Maximum value: 46.6
# First quartile (Q1): 17.5
# Median (Q2): 23.0
# Third quartile (Q3): 29.0

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 11.5
